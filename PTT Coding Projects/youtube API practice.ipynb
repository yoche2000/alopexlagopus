# %%
api_key="AIzaSyCjP1xmSOrc7m6ZfizqYBAkQrfKuUEs3cc"

# %%
pip install --upgrade google-api-python-client

# %%
from googleapiclient.discovery import build

service = build('youtube', 'v3', developerKey=api_key)

request = service.search().list(
            part="snippet",
            channelId = "UC1uv2Oq6kNxgATlCiez59hw",            
            order = "date",
            maxResults = "10"
          )
  
response = request.execute()

cid = response['items'][0]['snippet']['channelId']
cname = response['items'][0]['snippet']['channelTitle']

print(response)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'QRn3yUCCqn4F80jgOdMMcJPi6yU', 'nextPageToken': 'CAoQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 334, 'resultsPerPage': 10}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'WlQwCIB_yryH64fPv_SSO0RqU4Q', 'id': {'kind': 'youtube#video', 'videoId': '7Jjx13aacko'}, 'snippet': {'publishedAt': '2021-03-06T06:33:59Z', 'channelId': 'UC1uv2Oq6kNxgATlCiez59hw', 'title': '【To the Moon】【常闇トワ/ホロライブ】', 'description': '常闇トワ オリジナル曲「Palette」配信決定！ ▽詳細▽ https://towa.streamlink.to/palette "本ゲームは© Freebird Gamesに確認を得た上で配信・収益化を行なっております ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7Jjx13aacko/default_live.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/7Jjx13aacko/mqdefault_live.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/7Jjx13aacko/hqdefault_live.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Towa Ch. 常闇トワ', 'liveBroadcastContent': 'upcoming', 'publishTime': 
# ...

# %%
from googleapiclient.discovery import build
import os

api_key="AIzaSyCjP1xmSOrc7m6ZfizqYBAkQrfKuUEs3cc"

service = build('youtube', 'v3', developerKey=api_key)

def get_stat(key):
    request = service.search().list(
      part="snippet",
      q=key
    )
    response = request.execute()

    cid = response['items'][0]['snippet']['channelId']
    cname = response['items'][0]['snippet']['channelTitle']

    text = "Channel: " + cname + "\n"
    text += get_stat_by_id(cid)

    return text



def get_stat_by_id(key):
  request = service.channels().list(
      part="statistics",
      id=key
  )
  response2 = request.execute()
  info = ""
  
  print(response2)
  
  return(info)

# %%
get_stat('pewdiepie')
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'FIburdpkq1VHh2u5dwp4e4guM9E', 'pageInfo': {'totalResults': 0, 'resultsPerPage': 5}}
# 'Channel: PewDiePie\n'

# %%
get_stat_by_id(cid)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'aYEWMx97njUaXUQ_ZqiafX31eAc', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'VdFzvDvXecFjq9_wex-F4gDdLu0', 'id': 'UCS9uQI-jC3DE0L4IpXyvr6w', 'statistics': {'viewCount': '111713947', 'subscriberCount': '1020000', 'hiddenSubscriberCount': False, 'videoCount': '628'}}]}
# ''

# %%
lst = response["items"]
n = 0
for items in lst:
  if items['snippet']['liveBroadcastContent'] == "live":
  print(items)

print(n)
# Out:
# {'kind': 'youtube#searchResult', 'etag': '4RjJ8uFdM8IU2A1-a6bERecj8a4', 'id': {'kind': 'youtube#video', 'videoId': '_OEIMAyukuA'}, 'snippet': {'publishedAt': '2021-03-06T06:04:48Z', 'channelId': 'UC1uv2Oq6kNxgATlCiez59hw', 'title': '【APEX】#TOKONOSE\u3000でランク！プラチナからダイヤ？？【常闇トワ/ホロライブ】', 'description': '明日から #CRカップ カスタム始まる～～！ チーム名はVORUTOになりました✨ 【コラボ相手】 □一ノ瀬うるは @一ノ瀬うるは 本ゲームは © 2020 Electronic Arts Inc. の ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_OEIMAyukuA/default_live.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/_OEIMAyukuA/mqdefault_live.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/_OEIMAyukuA/hqdefault_live.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Towa Ch. 常闇トワ', 'liveBroadcastContent': 'live', 'publishTime': '2021-03-06T06:04:48Z'}}
# 0

# %%
# Out:
#   File "<ipython-input-67-ccaa1225c325>", line 1
#     curl https://www.googleapis.com/youtube/v3/liveBroadcasts?part=id%2Csnippet%2Cstatus&mine=true&broadcastStatus=active&key={YOUR_API_KEY}
#              ^
# SyntaxError: invalid syntax
